# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import os
from sklearn.neighbors import KDTree

from scipy.spatial import KDTree 
from shapely.geometry import Point

DATA_DIR = '../data/raw/'
INTERIM_DIR = '../data/interim/' 
PROCESSED_DIR = '../data/processed/'

# %%
df_pin = pd.read_csv('../data/interim/universe_pin.csv')
df_pin['pin10'] = df_pin['pin10'].astype(int)
df_pin
# Out:
#              pin10        lon        lat
# 0       2503106015 -87.623728  41.733446
# 1       2510117011 -87.616102  41.717261
# 2       2022402038 -87.610924  41.771698
# 3       2034101010 -87.622505  41.750465
# 4       2502207033 -87.587231  41.735210
# ...            ...        ...        ...
# 176256  1626309035 -87.722383  41.841593
# 176257  1323207013 -87.708859  41.952838
# 176258  2083090100        NaN        NaN
# 176259  2271090090        NaN        NaN
# 176260  1707112032 -87.678654  41.893399
#
# [176261 rows x 3 columns]

# %%
df_sales = pd.read_csv(os.path.join(DATA_DIR, 'sales_data.csv'))
df_sales
# Out:
# /var/folders/fk/9chv4jr11ln50p4dhsxntpcw0000gn/T/ipykernel_57015/3652251578.py:1: DtypeWarning: Columns (8,10,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sales = pd.read_csv(os.path.join(DATA_DIR, 'sales_data.csv'))
#                     pin    year  township_code   nbhd class  \
# 0        25031060150000  2024.0             70  70111   234
# 1        25101170110000  2024.0             70  70111   203
# 2        20224020380000  2024.0             70  70030   211
# 3        20341010100000  2024.0             70  70111   203
# 4        25022070330000  2024.0             70  70080   241
# ...                 ...     ...            ...    ...   ...
# 2615947  27034000541111  2024.0             28  28031   299
# 2615948  27214050741034  2024.0             28  28099   299
# 2615949  27214050741016  2024.0             28  28099   299
# 2615950  27022090100000  2024.0             28  28031   278
# 2615951  27123040020000  2024.0             28  28037   203
#
#                        sale_date  is_mydec_date  sale_price      doc_no  \
# 0        2024-01-16T00:00:00.000           True    260000.0  2402413181
# 1        2024-01-25T00:00:00.000           True    299900.0  2402913199
# 2        2024-01-04T00:00:00.000           True    385000.0  2402246046
# 3        2024-01-11T00:00:00.000           True    237000.0  2401813310
# 4        2024-01-10T00:00:00.000           True    455000.0  2402306427
# ...                          ...            ...         ...         ...
# 2615947  2024-12-02T00:00:00.000           True    185000.0  2435502119
# 2615948  2024-12-16T00:00:00.000           True    291500.0  2435218268
# 2615949  2024-12-16T00:00:00.000           True    291500.0  2435218268
# 2615950  2024-11-11T00:00:00.000           True    530000.0  2435202213
# 2615951  2024-12-18T00:00:00.000           True    455000.0  2436502015
#
#         deed_type mydec_deed_type  \
# 0        Warranty   Warranty Deed
# 1         Trustee    Trustee Deed
# 2        Warranty   Warranty Deed
# 3        Warranty   Warranty Deed
# 4        Warranty             NaN
# ...           ...             ...
# 2615947  Warranty             NaN
# 2615948  Executor             NaN
# 2615949  Executor             NaN
# 2615950   Trustee    Trustee Deed
# 2615951  Warranty   Warranty Deed
#
#                                                seller_name  is_multisale  \
# 0                                       CHRISTOPHER  SHAW          False
# 1                                   9731 FOREST LAND TRUST         False
# 2                                             ANNA  COUNTS         False
# 3                             NCRC HOUSING REHAB FUND, LLC         False
# 4                                          HAROLD  COLLINS          True
# ...                                                    ...           ...
# 2615947                                    ROBERT B. FICEK          True
# 2615948                                                NaN          True
# 2615949                                                NaN          True
# 2615950  THOMAS BOBERAND DONNA BOBER AS TRUSTEES UNDER ...         False
# 2615951                                  CHRISTOPHER SUJKA         False
#
#          num_parcels_sale                 buyer_name sale_type  \
# 0                     1.0         CALVIN  GRANDBERRY       NaN
# 1                     1.0           KIMBERLY J ADAMS       NaN
# 2                     1.0   JOSHUA ISHMAEL HERNANDEZ       NaN
# 3                     1.0           TRYNELL WILLIAMS       NaN
# 4                     2.0                        NaN       NaN
# ...                   ...                        ...       ...
# 2615947               2.0        GAYLINN M. VARKALIS       NaN
# 2615948               2.0                        NaN       NaN
# 2615949               2.0                        NaN       NaN
# 2615950               1.0  KAMALIDEEN O ABDUR-RAHMAN       NaN
# 2615951               1.0            ADRIAN A KALATA       NaN
#
#          sale_filter_same_sale_within_365  sale_filter_less_than_10k  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                      False
# 4                                   False                      False
# ...                                   ...                        ...
# 2615947                             False                      False
# 2615948                             False                      False
# 2615949                             False                      False
# 2615950                             False                      False
# 2615951                             False                      False
#
#          sale_filter_deed_type   row_id
# 0                        False  7573637
# 1                        False  7573642
# 2                        False  7573651
# 3                        False  7573654
# 4                        False  7573660
# ...                        ...      ...
# 2615947                  False  7693745
# 2615948                   True  7693746
# 2615949                   True  7693747
# 2615950                  False  7693748
# 2615951                  False  7693755
#
# [2615952 rows x 20 columns]

# %%
df_sales['pin10'] = df_sales['pin'].astype(str).str[:10].astype(int)
df_sales.dtypes
# Out:
# pin                                   int64
# year                                float64
# township_code                         int64
# nbhd                                  int64
# class                                object
# sale_date                            object
# is_mydec_date                          bool
# sale_price                          float64
# doc_no                               object
# deed_type                            object
# mydec_deed_type                      object
# seller_name                          object
# is_multisale                           bool
# num_parcels_sale                    float64
# buyer_name                           object
# sale_type                            object
# sale_filter_same_sale_within_365       bool
# sale_filter_less_than_10k              bool
# sale_filter_deed_type                  bool
# row_id                                int64
# pin10                                 int64
# dtype: object

# %%
df_merged = pd.merge(df_sales, df_pin, on='pin10', how='left')
df_merged
# Out:
#                     pin    year  township_code   nbhd class  \
# 0        25031060150000  2024.0             70  70111   234
# 1        25101170110000  2024.0             70  70111   203
# 2        20224020380000  2024.0             70  70030   211
# 3        20341010100000  2024.0             70  70111   203
# 4        25022070330000  2024.0             70  70080   241
# ...                 ...     ...            ...    ...   ...
# 2615947  27034000541111  2024.0             28  28031   299
# 2615948  27214050741034  2024.0             28  28099   299
# 2615949  27214050741016  2024.0             28  28099   299
# 2615950  27022090100000  2024.0             28  28031   278
# 2615951  27123040020000  2024.0             28  28037   203
#
#                        sale_date  is_mydec_date  sale_price      doc_no  \
# 0        2024-01-16T00:00:00.000           True    260000.0  2402413181
# 1        2024-01-25T00:00:00.000           True    299900.0  2402913199
# 2        2024-01-04T00:00:00.000           True    385000.0  2402246046
# 3        2024-01-11T00:00:00.000           True    237000.0  2401813310
# 4        2024-01-10T00:00:00.000           True    455000.0  2402306427
# ...                          ...            ...         ...         ...
# 2615947  2024-12-02T00:00:00.000           True    185000.0  2435502119
# 2615948  2024-12-16T00:00:00.000           True    291500.0  2435218268
# 2615949  2024-12-16T00:00:00.000           True    291500.0  2435218268
# 2615950  2024-11-11T00:00:00.000           True    530000.0  2435202213
# 2615951  2024-12-18T00:00:00.000           True    455000.0  2436502015
#
#         deed_type  ... num_parcels_sale                 buyer_name  sale_type  \
# 0        Warranty  ...              1.0         CALVIN  GRANDBERRY        NaN
# 1         Trustee  ...              1.0           KIMBERLY J ADAMS        NaN
# 2        Warranty  ...              1.0   JOSHUA ISHMAEL HERNANDEZ        NaN
# 3        Warranty  ...              1.0           TRYNELL WILLIAMS        NaN
# 4        Warranty  ...              2.0                        NaN        NaN
# ...           ...  ...              ...                        ...        ...
# 2615947  Warranty  ...              2.0        GAYLINN M. VARKALIS        NaN
# 2615948  Executor  ...              2.0                        NaN        NaN
# 2615949  Executor  ...              2.0                        NaN        NaN
# 2615950   Trustee  ...              1.0  KAMALIDEEN O ABDUR-RAHMAN        NaN
# 2615951  Warranty  ...              1.0            ADRIAN A KALATA        NaN
#
#          sale_filter_same_sale_within_365 sale_filter_less_than_10k  \
# 0                                   False                     False
# 1                                   False                     False
# 2                                   False                     False
# 3                                   False                     False
# 4                                   False                     False
# ...                                   ...                       ...
# 2615947                             False                     False
# 2615948                             False                     False
# 2615949                             False                     False
# 2615950                             False                     False
# 2615951                             False                     False
#
#         sale_filter_deed_type   row_id       pin10        lon        lat
# 0                       False  7573637  2503106015 -87.623728  41.733446
# 1                       False  7573642  2510117011 -87.616102  41.717261
# 2                       False  7573651  2022402038 -87.610924  41.771698
# 3                       False  7573654  2034101010 -87.622505  41.750465
# 4                       False  7573660  2502207033 -87.587231  41.735210
# ...                       ...      ...         ...        ...        ...
# 2615947                 False  7693745  2703400054 -87.840266  41.636986
# 2615948                  True  7693746  2721405074 -87.855523  41.592118
# 2615949                  True  7693747  2721405074 -87.855523  41.592118
# 2615950                 False  7693748  2702209010        NaN        NaN
# 2615951                 False  7693755  2712304002        NaN        NaN
#
# [2615952 rows x 23 columns]

# %%
# Drop all rows with missing lon/lat
df_merged = df_merged.dropna(subset=['lon', 'lat'])
df_merged
# Out:
#                     pin    year  township_code   nbhd class  \
# 0        25031060150000  2024.0             70  70111   234
# 1        25101170110000  2024.0             70  70111   203
# 2        20224020380000  2024.0             70  70030   211
# 3        20341010100000  2024.0             70  70111   203
# 4        25022070330000  2024.0             70  70080   241
# ...                 ...     ...            ...    ...   ...
# 2615944  15261030070000  2024.0             34  34010   212
# 2615946  27034000541063  2024.0             28  28031   299
# 2615947  27034000541111  2024.0             28  28031   299
# 2615948  27214050741034  2024.0             28  28099   299
# 2615949  27214050741016  2024.0             28  28099   299
#
#                        sale_date  is_mydec_date  sale_price      doc_no  \
# 0        2024-01-16T00:00:00.000           True    260000.0  2402413181
# 1        2024-01-25T00:00:00.000           True    299900.0  2402913199
# 2        2024-01-04T00:00:00.000           True    385000.0  2402246046
# 3        2024-01-11T00:00:00.000           True    237000.0  2401813310
# 4        2024-01-10T00:00:00.000           True    455000.0  2402306427
# ...                          ...            ...         ...         ...
# 2615944  2024-09-10T00:00:00.000           True    499999.0  2435223226
# 2615946  2024-12-02T00:00:00.000           True    185000.0  2435502119
# 2615947  2024-12-02T00:00:00.000           True    185000.0  2435502119
# 2615948  2024-12-16T00:00:00.000           True    291500.0  2435218268
# 2615949  2024-12-16T00:00:00.000           True    291500.0  2435218268
#
#         deed_type  ... num_parcels_sale                buyer_name  sale_type  \
# 0        Warranty  ...              1.0        CALVIN  GRANDBERRY        NaN
# 1         Trustee  ...              1.0          KIMBERLY J ADAMS        NaN
# 2        Warranty  ...              1.0  JOSHUA ISHMAEL HERNANDEZ        NaN
# 3        Warranty  ...              1.0          TRYNELL WILLIAMS        NaN
# 4        Warranty  ...              2.0                       NaN        NaN
# ...           ...  ...              ...                       ...        ...
# 2615944   Trustee  ...              2.0                       NaN        NaN
# 2615946  Warranty  ...              2.0       GAYLINN M. VARKALIS        NaN
# 2615947  Warranty  ...              2.0       GAYLINN M. VARKALIS        NaN
# 2615948  Executor  ...              2.0                       NaN        NaN
# 2615949  Executor  ...              2.0                       NaN        NaN
#
#          sale_filter_same_sale_within_365 sale_filter_less_than_10k  \
# 0                                   False                     False
# 1                                   False                     False
# 2                                   False                     False
# 3                                   False                     False
# 4                                   False                     False
# ...                                   ...                       ...
# 2615944                             False                     False
# 2615946                             False                     False
# 2615947                             False                     False
# 2615948                             False                     False
# 2615949                             False                     False
#
#         sale_filter_deed_type   row_id       pin10        lon        lat
# 0                       False  7573637  2503106015 -87.623728  41.733446
# 1                       False  7573642  2510117011 -87.616102  41.717261
# 2                       False  7573651  2022402038 -87.610924  41.771698
# 3                       False  7573654  2034101010 -87.622505  41.750465
# 4                       False  7573660  2502207033 -87.587231  41.735210
# ...                       ...      ...         ...        ...        ...
# 2615944                 False  7693689  1526103007 -87.838232  41.849476
# 2615946                 False  7693744  2703400054 -87.840266  41.636986
# 2615947                 False  7693745  2703400054 -87.840266  41.636986
# 2615948                  True  7693746  2721405074 -87.855523  41.592118
# 2615949                  True  7693747  2721405074 -87.855523  41.592118
#
# [918551 rows x 23 columns]

# %%
CTA_FILE_PATH = os.path.join(DATA_DIR, 'cta_l_stops.geojson')
gdf_cta = gpd.read_file(CTA_FILE_PATH)
gdf_cta.to_crs(epsg=4326, inplace=True)
gdf_cta.head()
# Out:
#   station_id           point_y  pknrd          legend           point_x  \
# 0        970  1896352.78926296  False       Blue Line  1144440.97667316
# 1         20  1901803.39560403  False      Green Line  1128608.76033842
# 2        610  1901950.19138017  False      Green Line  1133921.86037537
# 3        230  1937256.04587705   True       Blue Line  1118914.13069739
# 4       1700  1900828.68763513  False  Multiple Lines  1176812.47724731
#
#                      address    ada           longname  \
# 0       720 S. Cicero Avenue  False    Cicero-Congress
# 1         1 S. Harlem Avenue   True        Harlem-Lake
# 2     36 N. Ridgeland Avenue  False          Ridgeland
# 3  5800 N. Cumberland Avenue   True         Cumberland
# 4               29 N. Wabash   True  Washington/Wabash
#
#                                            lines                    geometry
# 0                           Blue Line (Congress)  POINT (-87.74517 41.87161)
# 1                              Green Line (Lake)  POINT (-87.80318 41.88685)
# 2                              Green Line (Lake)  POINT (-87.78366 41.88716)
# 3                                      Blue Line  POINT (-87.83803 41.98429)
# 4  Brown, Orange, Pink,  Purple (Express), Green  POINT (-87.62619 41.88322)

# %%
# Create Point objects from lat/lon columns
geometry = [Point(xy) for xy in zip(df_merged['lon'], df_merged['lat'])]

# %%
# Create a GeoDataFrame for sales data
gdf_properties = gpd.GeoDataFrame(
    df_merged,
    geometry=geometry,
    crs="EPSG:4326"
)
print(f"Properties converted to GeoDataFrame. Shape: {gdf_properties.shape}")
# Out:
# Properties converted to GeoDataFrame. Shape: (918551, 24)

# %%
# Convert CTA coordinates (Lon/Lat) to a 2D array
cta_coordinates = np.array(list(zip(gdf_cta.geometry.x, gdf_cta.geometry.y)))
# Convert property coordinates to a 2D array
property_coordinates = np.array(list(zip(gdf_properties.geometry.x, gdf_properties.geometry.y)))

# %%
# KDTree for fast nearest neighbor searching
tree = KDTree(cta_coordinates)
# Query the KDTree
distances, indices = tree.query(property_coordinates, k=1)

# %%
gdf_properties['min_distance_deg'] = distances
nearest_stations = gdf_cta.iloc[indices].reset_index(drop=True)
gdf_properties['nearest_cta_stop'] = nearest_stations['longname']
gdf_properties['nearest_cta_lines'] = nearest_stations['lines']

# %%
M_PER_DEGREE = 111111 
gdf_properties['min_distance_meters'] = gdf_properties['min_distance_deg'] * M_PER_DEGREE
gdf_properties[['pin', 'sale_price', 'min_distance_meters', 'nearest_cta_stop', 'nearest_cta_lines']].head()
# Out:
#               pin  sale_price  min_distance_meters nearest_cta_stop  \
# 0  25031060150000    260000.0           242.302900             87th
# 1  25101170110000    299900.0          1084.531512    95th/Dan Ryan
# 2  20224020380000    385000.0          1068.335623       King Drive
# 3  20341010100000    237000.0           297.112480             79th
# 4  25022070330000    455000.0          4169.116857             87th
#
#   nearest_cta_lines
# 0          Red Line
# 1          Red Line
# 2        Green Line
# 3          Red Line
# 4          Red Line

# %%
df_final = pd.DataFrame(gdf_properties.drop(columns=['geometry', 'min_distance_deg']))
df_final.to_csv(os.path.join(INTERIM_DIR, 'sales_data_enriched.csv'), index=False)
